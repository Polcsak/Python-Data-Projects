# %% [markdown]
# # TikTok Case Study
# ![TikTok-Logo.wine.png](attachment:08db7060-6d3d-43ea-af30-d554d8674607.png)

# %% [markdown]
# ## Background of TikTok
# TikTok users have the ability to submit reports that identify videos and comments that contain user claims. These reports identify content that needs to be reviewed by moderators. The process generates a large number of user reports that are challenging to consider in a timely manner.
#
# **TikTok is working on the development of a predictive model that can determine whether a video contains a claim or offers an opinion.** With a successful prediction model, TikTok can reduce the backlog of user reports and prioritize them more efficiently.
#
# ## TikTok data team members
#
# **Data team roles:**
# - Willow Jaffey - Data Science Lead
# - Rosie Mae Bradshaw - Data Science Manager
# - Orion Rainier - Data Scientist
#
# **Cross-functional team members:**
# - Mary Joanna Rodgers - Project Management Officer
# - Margery Adebowale - Finance Lead, Americas
# - Maika Abadi - Operations Lead
#
# Your TikTok team includes several managers overseeing operations. It is important to adapt your communication to their roles since their responsibilities are less technical. The members of the data team at TikTok are well versed in data analysis and data science. Messages to these more technical co-workers should be concise and specific.

# %% [markdown]
# # Phase 01 - Develop Project Proposal
# TikTok’s data team is in the earliest stages of the claims classification project. The following tasks are needed before the team can begin the data analysis process:
# A project proposal identifying the following:
# - Organize project tasks into milestones.
# - Classify tasks using the PACE workflow.
# - Identify relevant stakeholders.
#
# TikTok is asking for a project proposal that will create milestones for the tasks within the comment classification project.

# %% [markdown]
# ## 1.1 PACE methodology
# ![image.png](attachment:867b525b-a87b-4caa-9cf1-1fde1f97e76e.png)

# %% [markdown]
# ---
# ### 1.1.1 Plan Phase
# 1. **Objective:** Establish the project foundation, define scope, identify informational needs.
# 2. **Tasks:**
#  - Establish structure for project workflow
#  - Data source  (Make choices about the source of data and methods needed for EDA)
#  - Write a project proposal (A project proposal is the initial document used to define a project goal and scope)
# 3. **Summary:** Conceptualize the project scope and develop guiding steps.
# 4. **Outputs:**
#  - PACE document
#  - Project Proposal
#  - Defined Project Goal and scope
#  - Define a team

# %% [markdown]
# ---
# ### 1.1.2 Analyze Phase
# 1. **Objective:** Collect, prepare, and analyze data for the project.
# 2. **Tasks:**
#  - Compile summary information about the data (preliminary data analysis)
#  - Data exploration and cleaning (EDA report).
#  - Compute descriptive statistics (Analysis of testing results between two important variables).
#  - Visualization building (Build visualizations to help during EDA process)
# 3. **Summary:** Collect and prepare data for analysis, engage in exploratory data analysis (EDA).
# 4. **Outputs:**
#  - EDA report
#  - Visualizations of data
#  - Descriptive statistics about dataset
#  - Prepared data for model building in Construct Phase

# %% [markdown]
# ---
# ### 1.1.3 Construct Phase
# 1. **Objective:** Build, interpret, and revise models to uncover data correlations.
# 2. **Tasks:**
#  - Conduct hypothesis testing
#  - Build a regression model
#  - Build a machine learning model
#  - Advanced Visualizations building
# 3. **Summary:** Build models to reveal hidden data relationships.
# 4. **Outputs:**
#  - Functional Machine learning model
#  - Regression model
#  - Dashboards/visualizations

# %% [markdown]
# ---
# ### 1.1.4 Execute Phase
# 1. **Objective:** Deliver findings, present to stakeholders, incorporate feedback.
# 2. **Tasks:**
#  - Evaluating the model
#  - Communicate final insights with stakeholders
# 3. **Summary:** Present analysis results, receive and incorporate feedback.
# 4. **Outputs:**
#  - Report to all stakeholders
#  - Feedback from stakeholders

# %% [markdown]
# ## 1.2 Project Proposal
# Waze leadership has asked the data team to build a machine learning model to predict user
# churn. The model is based on data collected from users of the Waze app.

# %% [markdown]
# | Milestone Nr.       | Phase | Tasks     | Deliverables       | Relevant Stakeholder       |
# |---------------------|-------|-----------|--------------------|----------------------------|
# | 1      | Plan Phase   | Establish structure for project workflow       | Global-level project document   | Rosie Mae Bradshaw — DS Manager           |
# | 2        | Plan Phase  | Write a project proposal | Overview and goal of Project | Sylvester Esperanza — Senior Project Manager        |
# | 3    | Analyze Phase  | Preliminary summary information about the data        | Data files ready for EDA     | Chidi Ga — Senior Data Analyst           |
# | 4      | Analyze Phase  | Perform EDA       | EDA report & Cleaned dataset     | Chidi Ga — Senior Data Analyst       |
# | 5        | Analyze Phase  | Auxiliary visualization building         | Visualizations      | Sylvester Esperanza — Senior Project Manager        |
# | 6        | Analyze Phase  | Compute descriptive statistics         | Analysis of testing results between two important variables      | Sylvester Esperanza — Senior Project Manager        |
# | 7        | Analyze Phase  | Compute descriptive statistics         | Analysis of testing results between two important variables      | Sylvester Esperanza — Senior Project Manager        |
# | 8        | Construct Phase  | Conduct hypothesis testing         | Confirmation or denial of Hypothesis      | May Santner — Data Analysis Manager        |
# | 9        | Construct Phase  | Build a regression model         | Regression model      | Harriet Hadzic — Director of Data Analysis        |
# | 10        | Construct Phase  | Build a machine learning model        | Machine learning model      | Harriet Hadzic — Director of Data Analysis        |
# | 11       | Construct Phase  | Communicate final insights with stakeholders       | Report & Data visualizations to all stakeholders      | Harriet Hadzic — Director of Data Analysis        |

# %% [markdown]
# # Phase 02 - Data Analysis
# ## 2.1 Preliminary Data Analysis
# Build a data frame for the claim’s classification data. After the data frame is complete, you will organize the claims data for the process of exploratory data analysis, and update the team on your progress and insights.The following tasks are needed before the team can begin the data analysis process:
# - Acquaint you with the data
# - Compile summary information about the data
# - Begin the process of EDA and reveal insights contained in the data
# - Prepare you for more in-depth EDA, hypothesis testing, and statistical analysis
#
# **The goal** is to construct a dataframe in Python, perform a cursory inspection of the provided dataset, and inform TikTok data team members of your findings.

# %% [markdown]
# ---
# ### 2.1.1 Imports and data loading

# %%
# Import packages
import pandas as pd
import numpy as np

# %%
# Load dataset into dataframe
df = pd.read_csv("/kaggle/input/tiktok-dataset/tiktok_dataset.csv")

# %% [markdown]
# ---
# ### 2.1.2 Understand the data - Inspect the data

# %%
# Display and examine the first five rows of the dataframe
df.head(5)
# Out:
#    # claim_status    video_id  video_duration_sec  \
# 0  1        claim  7017666017                  59
# 1  2        claim  4014381136                  32
# 2  3        claim  9859838091                  31
# 3  4        claim  1866847991                  25
# 4  5        claim  7105231098                  19
#
#                             video_transcription_text verified_status  \
# 0  someone shared with me that drone deliveries a...    not verified
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
# 4  someone shared with me that the number of busi...    not verified
#
#   author_ban_status  video_view_count  video_like_count  video_share_count  \
# 0      under review          343296.0           19425.0              241.0
# 1            active          140877.0           77355.0            19034.0
# ...

# %%
# Get summary info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19382 entries, 0 to 19381
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19382 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19382 non-null  int64
#  3   video_duration_sec        19382 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19382 non-null  object
#  6   author_ban_status         19382 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.8+ MB

# %%
# Get summary statistics
df.describe()
# Out:
#                   #      video_id  video_duration_sec  video_view_count  \
# count  19382.000000  1.938200e+04        19382.000000      19084.000000
# mean    9691.500000  5.627454e+09           32.421732     254708.558688
# std     5595.245794  2.536440e+09           16.229967     322893.280814
# min        1.000000  1.234959e+09            5.000000         20.000000
# 25%     4846.250000  3.430417e+09           18.000000       4942.500000
# 50%     9691.500000  5.618664e+09           32.000000       9954.500000
# 75%    14536.750000  7.843960e+09           47.000000     504327.000000
# max    19382.000000  9.999873e+09           60.000000     999817.000000
#
#        video_like_count  video_share_count  video_download_count  \
# count      19084.000000       19084.000000          19084.000000
# mean       84304.636030       16735.248323           1049.429627
# std       133420.546814       32036.174350           2004.299894
# ...

# %% [markdown]
# - The dataframe contains a collection of categorical, text, and numerical data. Each row represents a distinct TikTok video that presents either a claim or an opinion and the accompanying metadata about that video.
# - The dataframe contains five float64s, three int64s, and four objects. There are 19,382 observations, but some of the variables are missing values, including claim status, the video transcripton, and all of the count variables.
# - Many of the count variables seem to have outliers at the high end of the distribution. They have very large standard deviations and mean values that are very high compared to median values.

# %% [markdown]
# ---
# ### 2.1.3 Investigate the variables

# %%
# Different values for claim_status column
df['claim_status'].value_counts(normalize = True)
# Out:
# claim_status
# claim      0.503458
# opinion    0.496542
# Name: proportion, dtype: float64

# %% [markdown]
# The counts of each claim status are quite balanced.
# - **Claim status has 50.3%** proportion from dataset
# - **Opinion status has 49.6%** proportion from dataset

# %%
# Difference between claims and opinions in the average view count of videos:

# Claims:
print("Info Claims:")
claims = df[df['claim_status'] == 'claim']
print('Mean view count claims:', claims['video_view_count'].mean())
print('Median view count claims:', claims['video_view_count'].median())

# Opinions:
print("")
print("Info Opinions:")
opinions = df[df['claim_status'] == 'opinion']
print('Mean view count opinions:', opinions['video_view_count'].mean())
print('Median view count opinions:', opinions['video_view_count'].median())
# Out:
# Info Claims:
# Mean view count claims: 501029.4527477102
# Median view count claims: 501555.0
#
# Info Opinions:
# Mean view count opinions: 4956.43224989447
# Median view count opinions: 4953.0

# %% [markdown]
# The mean and the median within each claim category are close to one another, but there is **a large difference between view counts for videos labeled as claims and videos labeled as opinions.**

# %%
# Get counts for each group combination of claim status and author ban status
df.groupby(['claim_status', 'author_ban_status']).count()[['#']].rename(columns={"#": "Total Count"}).reset_index()
# Out:
#   claim_status author_ban_status  Total Count
# 0        claim            active         6566
# 1        claim            banned         1439
# 2        claim      under review         1603
# 3      opinion            active         8817
# 4      opinion            banned          196
# 5      opinion      under review          463

# %%
# Get proportions for each group combination of claim status and author ban status
value_counts_df = df[["claim_status", "author_ban_status"]].value_counts(normalize=True).reset_index()
value_counts_df.columns = ["claim_status", "author_ban_status", "percentage"]
value_counts_df["percentage"] = value_counts_df["percentage"]*100


value_counts_df.sort_values(by=["claim_status"], ascending=True)
# Out:
#   claim_status author_ban_status  percentage
# 1        claim            active   34.405785
# 2        claim      under review    8.399707
# 3        claim            banned    7.540348
# 0      opinion            active   46.201006
# 4      opinion      under review    2.426116
# 5      opinion            banned    1.027038

# %% [markdown]
# There are many more claim videos with banned authors than there are opinion videos with banned authors (approx. 7.5x more). This could mean a number of things, including the possibilities that:
# * Claim videos are more strictly policed than opinion videos
# * Authors must comply with a stricter set of rules if they post a claim than if they post an opinion
#
# Also, it should be noted that there's no way of knowing if claim videos are inherently more likely than opinion videos to result in author bans, or if authors who post claim videos are more likely to post videos that violate terms of service.
#
# Finally, while you can use this data to draw conclusions about banned/active authors, you cannot draw conclusions about banned videos. You cannot say for sure that a **specific video caused the ban. It is possible that banned authors also had videos that followed the rules.**

# %%
# investigating engagement levels, now focusing on `author_ban_status`:
df.groupby(['author_ban_status']).agg(
    {'video_view_count': ['count', 'mean', 'median'],
     'video_like_count': ['count', 'mean', 'median'],
     'video_share_count': ['count', 'mean', 'median']
     })
# Out:
#                   video_view_count                          video_like_count  \
#                              count           mean    median            count
# author_ban_status
# active                       15383  215927.039524    8616.0            15383
# banned                        1635  445845.439144  448201.0             1635
# under review                  2066  392204.836399  365245.5             2066
#
#                                            video_share_count                \
#                             mean    median             count          mean
# author_ban_status
# active              71036.533836    2222.0             15383  14111.466164
# banned             153017.236697  105573.0              1635  29998.942508
# under review       128718.050339   71204.5              2066  25774.696999
#
#
#                     median
# author_ban_status
# active               437.0
# banned             14468.0
# under review        9444.0

# %% [markdown]
# A few observations stand out:
# * Banned authors and those under review get far more views, likes, and shares than active authors.
# * In most groups, the mean is much greater than the median, which indicates that there are some videos with very high engagement counts.
#
# Now, create three new columns to help better understand engagement rates:
# * `likes_per_view`: represents the number of likes divided by the number of views for each video
# * `comments_per_view`: represents the number of comments divided by the number of views for each video
# * `shares_per_view`: represents the number of shares divided by the number of views for each video

# %%
# Create a likes_per_view column
df['likes_per_view'] = df['video_like_count'] / df['video_view_count']

# Create a comments_per_view column
df['comments_per_view'] = df['video_comment_count'] / df['video_view_count']

# Create a shares_per_view column
df['shares_per_view'] = df['video_share_count'] / df['video_view_count']

# %%
# Use `groupby()` to compile the information in each of the three newly created columns 
# for each combination of categories of claim status and author ban status, then use `agg()` to calculate
# the count, the mean, and the median of each group.
df.groupby(['claim_status', 'author_ban_status']).agg(
    {'likes_per_view': ['count', 'mean', 'median'],
     'comments_per_view': ['count', 'mean', 'median'],
     'shares_per_view': ['count', 'mean', 'median']})
# Out:
#                                likes_per_view                      \
#                                         count      mean    median
# claim_status author_ban_status
# claim        active                      6566  0.329542  0.326538
#              banned                      1439  0.345071  0.358909
#              under review                1603  0.327997  0.320867
# opinion      active                      8817  0.219744  0.218330
#              banned                       196  0.206868  0.198483
#              under review                 463  0.226394  0.228051
#
#                                comments_per_view                      \
#                                            count      mean    median
# claim_status author_ban_status
# claim        active                         6566  0.001393  0.000776
#              banned                         1439  0.001377  0.000746
#              under review                   1603  0.001367  0.000789
# ...

# %% [markdown]
# We know that videos by banned authors and those under review tend to get far more views, likes, and shares than videos by non-banned authors. **However, *when a video does get viewed*, its engagement rate is less related to author ban status and more related to its claim status.**
#
# Also, we know that claim videos have a higher view rate than opinion videos, but this tells us that claim videos also have a higher rate of likes on average, so they are more favorably received as well. Furthermore, they receive more engagement via comments and shares than opinion videos.
#
# **Note that for claim videos, banned authors have slightly higher likes/view and shares/view rates than active authors or those under review. However, for opinion videos, active authors and those under review both get higher engagement rates than banned authors in all categories.**

# %% [markdown]
# ---
# ### 2.1.4 Key results from preliminary analysis
# 1. **Obtained dataset contains missing data** for variables claim status, video_transcription_text and all count columns.
# 1. Of the 19,382 samples in this dataset, **just under 50% are claims&mdash;9,608 of them.**
# 2. **Engagement level is strongly correlated with claim status.** This should be a focus of further inquiry. (Videos with claim status has significantly higher median numbers of views in comparison with opinion - 501,555 vs 4,953 views)
# 3. **Videos with banned authors have significantly higher engagement than videos with active authors.** Videos with authors under review fall between these two categories in terms of engagement levels.
# 4. **Videos with claim status has more banned authors than videos with opinion status** (143,900 vs 19,600 banned authors)

# %% [markdown]
# ## 2.2 Executive Summary of Preliminary Analysis
# ![image.png](attachment:4de50819-55fd-492b-b5f7-8923be45462a.png)

# %% [markdown]
# ## 2.3 EDA report and visualizations
# **The purpose** of this part is to conduct exploratory data analysis (EDA) on a provided data set. Your mission is to continue the investigation you began in preliminary data analysis and perform further EDA on this data with the aim of learning more about the variables. **Of particular interest is information related to what distinguishes claim videos from opinion videos.**
#
# The best approach to start EDA is to visualize distribution of each counts columns. After that, compare each variable by claim status.
#
# The visualizations most helpful for considering the distribution of the data include box plots and histograms. Visualizing the distribution of the data can inform the next steps and considerations in data analysis. For example, data distribution will inform which types of modeling is needed.

# %% [markdown]
# ---
# ### 2.3.1 Import packages for data visualization and ignoring warnings

# %%
# Import packages for data visualization and ignoring warnings
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ---
# ### 2.3.2 Compare distribution of count columns

# %%
# Create a boxplot to visualize distribution of `video_duration_sec` & `video_like_count`
fig, ax = plt.subplots(2, 2, figsize=(10, 6))

# First subplot: Boxplot of video_duration_sec
ax[0,0].set_title('Video Duration (sec) - Boxplot')
sns.boxplot(x=df['video_duration_sec'], ax=ax[0,0])

# Second subplot: Boxplot of View Count
ax[0,1].set_title('Video View Count - Boxplot')
sns.boxplot(x=df['video_view_count'], ax=ax[0,1])

# Third subplot: Histogram of video_duration_sec
sns.histplot(df['video_duration_sec'],bins=range(0,66,5), ax=ax[1,0])

# Fourth subplot: Histogram of View Count
ax[1,1].set_title('Video View Count - Histogram')
sns.histplot(df['video_view_count'], bins=range(0, (10**6 + 1), 10**5), ax=ax[1,1])

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. **All videos are 5-60 seconds in length, and the distribution is uniform.**
# 2. **View Count has a very uneven distribution, with more than half the videos receiving fewer than 100,000 views. Distribution of view counts > 100,000 views is uniform.**

# %%
# Boxplot & histogram to visualize distribution of `video_like_count` & `video_comment_count`:
fig, ax = plt.subplots(2, 2, figsize=(10, 6))
labels = [0] + [str(i) + 'k' for i in range(100, 701, 100)]

# First subplot: Boxplot Like Count
ax[0,0].set_title('Video Like Count - Boxplot')
sns.boxplot(x=df['video_like_count'], ax=ax[0,0])
ax[0,0].set_xticks(range(0, 7 * 10**5 + 1, 10**5), labels=labels)

# Second subplot: Boxplot Comment Count
ax[0,1].set_title('Video Comment Count - Boxplot')
sns.boxplot(x=df['video_comment_count'], ax=ax[0,1])

# Third subplot: Histogram of Like Count
ax[1,0].set_title('Video Like Count - Histogram')
sns.histplot(df['video_like_count'], bins=range(0, (7 * 10**5 + 1), 10**5), ax=ax[1,0])
ax[1,0].set_xticks(range(0, 7 * 10**5 + 1, 10**5), labels=labels)

# Fourth subplot: Histogram of Comment Count
ax[1,1].set_title('Video Comment Count - Histogram')
sns.histplot(df['video_comment_count'], bins=range(0,(3001),100), ax=ax[1,1])

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# **Similar to view count, there are far more videos with lower likes/comments than there are videos with higher numbers. However, in this case, there is more of a taper, as the data skews right, with many videos at the upper extremity of like/comment count.**

# %%
# Create a boxplot & histogram to visualize distribution of `video_share_count` & `video_download_count`
fig, ax = plt.subplots(2, 2, figsize=(10, 6))

# First subplot: Boxplot
ax[0,0].set_title('Video Share Count - Boxplot')
sns.boxplot(x=df['video_share_count'], ax=ax[0,0])

# Second subplot: Boxplot of Download Count
ax[0,1].set_title('Video Download Count - Boxplot')
sns.boxplot(x=df['video_download_count'], ax=ax[0,1])

# Third subplot: Histogram of Share Count
ax[1,0].set_title('Video Share Count - Histogram')
sns.histplot(df['video_share_count'], bins=range(0,(270001),10000), ax=ax[1,0])

# Fourth subplot: Histogram of Download Count
sns.histplot(df['video_download_count'], bins=range(0,(15001),500), ax=ax[1,1])
plt.title('Video download count histogram');

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. **The overwhelming majority of videos had fewer than 10,000 shares. The distribution is very skewed to the right.**
# 2. **The majority of videos were downloaded fewer than 500 times, but some were downloaded over 12,000 times. Again, the data is very skewed to the right.**

# %% [markdown]
# ---
# ### 2.3.3 Comparison of Claim status by verification status

# %%
# Aggregate data
agg_data = df.groupby(["verified_status", "claim_status"])[["video_view_count"]].agg(["count"]).reset_index()
agg_data.columns = ['verified_status', 'claim_status', 'count']

# Create a bar plot
plt.figure(figsize=(10,6))

sns.barplot(
    data=agg_data,
    x="claim_status",
    y="count",
    hue="verified_status"
)

# Add a title for better readability
plt.title('Comparison of Claim status by verification status')

# Add labels for better readability
plt.xlabel('Claim status')
plt.ylabel('Count')

# Display the plot
plt.show()

# %% [markdown]
# **There are far fewer verified users than unverified users, but if a user *is* verified, they are much more likely to post opinions.**

# %% [markdown]
# ---
# ### 2.3.4 Comparison of Claim status by author ban status

# %%
# Create a histogram
agg_data = df.groupby(["author_ban_status", "claim_status"])[["video_view_count"]].agg(["count"]).reset_index()
agg_data.columns = ['author_ban_status', 'claim_status', 'count']

# Create a bar plot
plt.figure(figsize=(10,6))
sns.barplot(
    data=agg_data,
    x="claim_status",
    y="count",
    hue="author_ban_status",
    hue_order=['active', 'under review', 'banned'],
    palette={'active':'green', 'under review':'orange', 'banned':'red'},
    alpha=0.5
    )   

# Add a title for better readability
plt.title('Comparison of Claim status by author ban status')

# Add labels for better readability
plt.xlabel('Claim status')
plt.ylabel('Count')

# Display the plot
plt.show()

# %% [markdown]
# **For both claims and opinions, there are many more active authors than banned authors or authors under review; however, the proportion of active authors is far greater for opinion videos than for claim videos. Again, it seems that authors who post claim videos are more likely to come under review and/or get banned.**

# %% [markdown]
# ---
# ### 2.3.5 Compare Median view counts by ban status

# %%
# Create a ban_status_counts dataframe
ban_status_counts = df.groupby(['author_ban_status']).median(
    numeric_only=True).reset_index()
ban_status_counts.head()
# Out:
#   author_ban_status        #      video_id  video_duration_sec  \
# 0            active  10966.0  5.624036e+09                33.0
# 1            banned   5304.0  5.563176e+09                32.0
# 2      under review   6175.5  5.607722e+09                31.0
#
#    video_view_count  video_like_count  video_share_count  \
# 0            8616.0            2222.0              437.0
# 1          448201.0          105573.0            14468.0
# 2          365245.5           71204.5             9444.0
#
#    video_download_count  video_comment_count  likes_per_view  \
# 0                  28.0                  5.0        0.254227
# 1                 892.0                209.0        0.325045
# 2                 610.5                136.5        0.290504
#
#    comments_per_view  shares_per_view
# 0           0.000421         0.038429
# 1           0.000658         0.048507
# 2           0.000602         0.045357

# %%
# Create a bar plot
plt.figure(figsize=(10,6))
sns.barplot(
    data=ban_status_counts,
    x="author_ban_status",
    y = "video_view_count",
    order=['active', 'under review', 'banned'],
    palette={'active':'green', 'under review':'orange', 'banned':'red'},
    alpha=0.5
)

plt.title("Median view count by ban status")
plt.show()

# %% [markdown]
# **The median view counts for non-active authors are many times greater than the median view count for active authors. Since you know that non-active authors are more likely to post claims, and that videos by non-active authors get far more views on aggregate than videos by active authors, then `video_view_count` might be a good indicator of claim status.**
#
# **Indeed, a quick check of the median view count by claim status bears out this assessment:**

# %%
df.groupby('claim_status')['video_view_count'].median()
# Out:
# claim_status
# claim      501555.0
# opinion      4953.0
# Name: video_view_count, dtype: float64

# %% [markdown]
# ---
# ### 2.3.6 Total views by claim status

# %%
fig = plt.figure(figsize=(7,7))
plt.pie(df.groupby('claim_status')['video_view_count'].sum(), labels=['claim', 'opinion'])
plt.title('Total views by video claim status');

# %% [markdown]
# **The overall view count is dominated by claim videos even though there are roughly the same number of each video in the dataset.**

# %% [markdown]
# ---
# ### 2.3.7 Determine outliers

# %%
count_cols = ['video_view_count',
              'video_like_count',
              'video_share_count',
              'video_download_count',
              'video_comment_count',
              ]

for column in count_cols:
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    median = df[column].median()
    outlier_threshold = median + 1.5*iqr

    # Count the number of values that exceed the outlier threshold
    outlier_count = (df[column] > outlier_threshold).sum()
    print(f'Number of outliers, {column}:', outlier_count)
# Out:
# Number of outliers, video_view_count: 2343
# Number of outliers, video_like_count: 3468
# Number of outliers, video_share_count: 3732
# Number of outliers, video_download_count: 3733
# Number of outliers, video_comment_count: 3882

# %%
# Create a scatterplot of `video_view_count` versus `video_like_count` for opinions only
fig, ax = plt.subplots(2, 1, figsize=(10, 12))

opinion = df[df['claim_status']=='opinion']
ax[0].set_title("`video_view_count` versus `video_like_count` for opinions only")
sns.scatterplot(x=opinion["video_view_count"], y=opinion["video_like_count"],
                 s=10, alpha=.3, ax=ax[0])

claim = df[df['claim_status']=='claim']
ax[1].set_title("`video_view_count` versus `video_like_count` for claims only")
sns.scatterplot(x=claim["video_view_count"], y=claim["video_like_count"],
                 s=10, alpha=.3, ax=ax[1])

plt.show()

# %% [markdown]
# **further investigate distinctive characteristics that apply only to claims or only to opinions. Also, I want to consider other variables that might be helpful in understanding the data.**

# %% [markdown]
# ## 2.4 Executive Summary of EDA
#
# ![image.png](attachment:b6afa84b-353e-4db8-a8e8-f061e33a5cbd.png)

# %% [markdown]
# # Phase 03 - Construct Phase
#
# ## 3.1 Hypothesis Testing
# You will conduct hypothesis testing on the data for the claims classification data. You’ve been asked to investigate TikTok's user claim dataset to determine which hypothesis testing method best serves the data and the claims classification project.
#
# - Implement a hypothesis test
# - Communicate insights with stakeholders within TikTok

# %% [markdown]
# ---
# ### 3.1.1 Import statistical packages

# %%
from scipy import stats
import statsmodels.api as sm

# %% [markdown]
# ---
# ### 3.1.2 Data Preparation and Research Question
#
# 1. Do videos from verified accounts and videos unverified accounts have different average view counts?
# 2. Is there a relationship between the account being verified and the associated videos' view counts?

# %%
# Drop rows with missing values
df = df.dropna(axis=0)

# %%
# Check for missing values
df.isna().sum()
# Out:
# #                           0
# claim_status                0
# video_id                    0
# video_duration_sec          0
# video_transcription_text    0
# verified_status             0
# author_ban_status           0
# video_view_count            0
# video_like_count            0
# video_share_count           0
# video_download_count        0
# video_comment_count         0
# likes_per_view              0
# comments_per_view           0
# shares_per_view             0
# dtype: int64

# %% [markdown]
# The goal is to prove relationship between `verified_status` and `video_view_count`. To approach this task first examine the mean values of `video_view_count` for each group of `verified_status` in the sample data.

# %%
# Compute the mean `video_view_count` for each group in `verified_status`
df.groupby("verified_status")["video_view_count"].mean().reset_index()
# Out:
#   verified_status  video_view_count
# 0    not verified     265663.785339
# 1        verified      91439.164167

# %% [markdown]
# ---
# ### 3.1.2 State the null hypothesis and the alternative hypothesis
#
# **$H_0$**: There is no difference in number of views between TikTok videos posted by verified accounts and TikTok videos posted by unverified accounts (any observed difference in the sample data is due to chance or sampling variability).
#
# **$H_A$**: There is a difference in number of views between TikTok videos posted by verified accounts and TikTok videos posted by unverified accounts (any observed difference in the sample data is due to an actual difference in the corresponding population means).

# %% [markdown]
# ---
# ### 3.1.3 Choose a signficance level
# For this hypothesis test we choose 5% as the significance level and proceed with a two-sample t-test.

# %% [markdown]
# ---
# ### 3.1.4 A/B testing

# %%
# Conduct a two-sample t-test to compare means

# Save each sample in a variable
not_verified = df[df["verified_status"] == "not verified"]["video_view_count"]
verified = df[df["verified_status"] == "verified"]["video_view_count"]

# Implement a t-test using the two samples
stats.ttest_ind(a=not_verified, b=verified, equal_var=False)
# Out:
# TtestResult(statistic=25.499441780633777, pvalue=2.6088823687177823e-120, df=1571.163074387424)

# %% [markdown]
# ---
# ### 3.1.5 Reject or fail to reject the null hypothesis
# Since the p-value is extremely small (much smaller than the significance level of 5%), you reject the null hypothesis. You conclude that there **is** a statistically significant difference in the mean video view count between verified and unverified accounts on TikTok.

# %% [markdown]
# ---
# ### 3.1.6 Conclusion
# The analysis shows that there is a statistically significant difference in the average view counts between videos from verified accounts and videos from unverified accounts. This suggests there might be fundamental behavioral differences between these two groups of accounts.
#
# It would be interesting to investigate the root cause of this behavioral difference. For example, do unverified accounts tend to post more clickbait-y videos? Or are unverified accounts associated with spam bots that help inflate view counts?
#
# The next step will be to build a regression model on verified_status. A regression model is the natural next step because the end goal is to make predictions on claim status. A regression model for verified_status can help analyze user behavior in this group of verified users. Technical note to prepare regression model: because the data is skewed, and there is a significant difference in account types, it will be key to build a logistic regression model.

# %% [markdown]
# ## 3.2 Executive Summary from Hypothesis Testing
#
# ![image.png](attachment:d5e65ccb-4bd0-43ce-afae-f564f9777bc4.png)
